# %%
# !pip install pyvi

import torch
import torch.nn as nn
from torch.utils.data import Dataset,DataLoader
from torch.nn.utils.rnn import pad_sequence

import matplotlib.pyplot as plt
import re
import string
import numpy as np
from pyvi import ViTokenizer
from torchvision import transforms
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
# Out:
# Requirement already satisfied: pyvi in /usr/local/lib/python3.7/dist-packages (0.1.1)
# Requirement already satisfied: sklearn-crfsuite in /usr/local/lib/python3.7/dist-packages (from pyvi) (0.3.6)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.7/dist-packages (from pyvi) (1.0.1)
# Requirement already satisfied: joblib>=0.11 in /usr/local/lib/python3.7/dist-packages (from scikit-learn->pyvi) (1.1.0)
# Requirement already satisfied: scipy>=1.1.0 in /usr/local/lib/python3.7/dist-packages (from scikit-learn->pyvi) (1.4.1)
# Requirement already satisfied: numpy>=1.14.6 in /usr/local/lib/python3.7/dist-packages (from scikit-learn->pyvi) (1.19.5)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from scikit-learn->pyvi) (3.0.0)
# Requirement already satisfied: tabulate in /usr/local/lib/python3.7/dist-packages (from sklearn-crfsuite->pyvi) (0.8.9)
# Requirement already satisfied: python-crfsuite>=0.8.3 in /usr/local/lib/python3.7/dist-packages (from sklearn-crfsuite->pyvi) (0.9.7)
# Requirement already satisfied: tqdm>=2.0 in /usr/local/lib/python3.7/dist-packages (from sklearn-crfsuite->pyvi) (4.62.3)
# Requirement already satisfied: six in /usr/local/lib/python3.7/dist-packages (from sklearn-crfsuite->pyvi) (1.15.0)

# %%
# %cd /content/drive/MyDrive/DeepLearning/TH/CuoiKy/Seq2Seq/MachineTranslation
# Out:
# /content/drive/MyDrive/DeepLearning/TH/CuoiKy/Seq2Seq/MachineTranslation

# %%
engs = []
vies = []
with open('Data/eng-vie.txt','r') as f:
    for line in f: 
        line = line.split('\t')
        engs.append(line[0])
        vies.append(line[1])

# %%
print(len(engs), len(vies))
print(engs[1000], vies[1000])
# Out:
# 6369 6369
# He has a foreign car. Ông ấy có một chiếc xe hơi nước ngoài.

# %%
#tách từ
def token_vi(sentence):
        return ViTokenizer.tokenize(sentence)
    
# xử lý
def clean_sentence(text, language = 'en'):
    text = text.lower()
    if language == 'en':
        text = re.sub(r"i'm", "i am", text)
        text = re.sub(r"he's", "he is", text)
        text = re.sub(r"she's", "she is", text)
        text = re.sub(r"it's", "it is", text)
        text = re.sub(r"that's", "that is", text)
        text = re.sub(r"what's", "that is", text)
        text = re.sub(r"where's", "where is", text)
        text = re.sub(r"how's", "how is", text)
        text = re.sub(r"\'ll", " will", text)
        text = re.sub(r"\'ve", " have", text)
        text = re.sub(r"\'re", " are", text)
        text = re.sub(r"\'d", " would", text)
        text = re.sub(r"\'re", " are", text)
        text = re.sub(r"won't", "will not", text)
        text = re.sub(r"can't", "cannot", text)
        text = re.sub(r"n't", " not", text)
        text = re.sub(r"n'", "ng", text)
        text = re.sub(r"'bout", "about", text)
        text = re.sub(r"'til", "until", text)
        #text = re.sub(r"([.!?])", r" \1", text)
        text = re.sub(r"[-()\"#/@;:<>{}`+=~|,!.?]", " ", text)      
    else:
        table = str.maketrans('','',string.punctuation)
        text = text.translate(table)
    text = text.replace('  ',' ',5)
    text = text.strip()
    return text

# %%
engs_all = [clean_sentence(i) for i in engs]
vies_all = [token_vi(clean_sentence(i)) for i in vies]

# %%
#view
list(zip(engs_all[100:120], vies_all[100:120]))
# Out:
# [('hang on tom', 'chờ chút tom'),
#  ('i am at home', 'tôi đang ở nhà'),
#  ('i am curious', 'tôi tò_mò'),
#  ('i do not know', 'tôi không biết'),
#  ('i do not know', 'tôi không hiểu'),
#  ('i hear music', 'tôi nghe nhạc'),
#  ('i like bread', 'tôi thích bánh_mì'),
#  ('i like bread', 'tôi thích bánh mỳ'),
#  ('i will not lose', 'tôi không thua đâu'),
#  ('i would buy that', 'lấy cho tôi cái kia'),
#  ('i am not free', 'tôi không rảnh'),
#  ('i am not free', 'em không rảnh'),
#  ('i am not free', 'mình không rảnh'),
#  ('i am not free', 'tao không rảnh'),
#  ('i am not free', 'tớ không rảnh'),
#  ('i am retiring', 'tôi sắp nghỉ hưu'),
#  ('is tom there', 'tom có ở đó không'),
#  ('it is raining', 'trời đang mưa'),
#  ('it is so easy', 'quá dễ'),
#  ('it is so hard', 'việc này thật là khó')]

# %%
class Vocab():
    def __init__(self):
        self.n_words = 3
        self.word2index = {'<startseq>':1,'<endseq>':2,'<pad>':0, '<none>':3}
        self.word2count = {}
        self.index2word = {1:'<startseq>',2:'<endseq>',0:'<pad>',3:'<none>'}
        self.max_length = 0

        self._word_count = {}
    
    def fit(self, all_train_caption):
        # Thêm các từ vào từ điển và cập nhập các thông tin cơ bản của vocab
        for sentence in all_train_caption: 
          self.addSentence(sentence)
    
    def addSentence(self,sentence):
        sentence = sentence.split()
        if len(sentence)>self.max_length:
          self.max_length = len(sentence)
        for word in sentence:
          self.addWord(word)
    def addWord(self, word):
        if (word not in self.word2index):
          self.word2index[word] = self.n_words
          self.word2count[word] = 1
          self.index2word[self.n_words] = word
          self.n_words += 1
        else:
          self.word2count[word] += 1

# %%
vi_vocab = Vocab()
vi_vocab.fit(vies_all)


en_vocab = Vocab()
en_vocab.fit(engs_all)

# %%
print(f'Độ dài bộ từ điển \nvi:{vi_vocab.n_words}\nen:{en_vocab.n_words}')
# Out:
# Độ dài bộ từ điển
# vi:3383
# en:3503

# %%
# tạo dataset 
class Dataset_en_vi(Dataset):
    def __init__(self,engs, vies,vi_vocab,en_vocab):

        self.engs = engs
        self.vies = vies
        self.transforms = transforms
        self.vi_vocab = vi_vocab
        self.en_vocab = en_vocab
    def tensorFromSentence(self,sentence,vocab,input= False):
        if input ==False:
            sentence = '<startseq> '+sentence +' <endseq>' 
        indexes = []
        for word in sentence.split():
            if word in vocab.word2index:
                indexes.append(vocab.word2index[word])
        return torch.tensor(indexes, dtype = torch.long)
    def __getitem__(self, index):
        input = self.tensorFromSentence(self.engs[index],en_vocab, input = True)
        target = self.tensorFromSentence(self.vies[index],vi_vocab)
        return input, target
    def __len__(self):
        return len(self.engs)

# %%
dataset = Dataset_en_vi(engs_all ,vies_all,vi_vocab,en_vocab)
dataset.__len__()
# Out:
# 6369

# %%
train_dataset, test_dataset = torch.utils.data.random_split(dataset, [5000, 1369])

# %%
input, target = train_dataset[21]
print(' '.join([en_vocab.index2word[i.item()] for i in input ]))
print(' '.join([vi_vocab.index2word[i.item()] for i in target ]))
# Out:
# mary wore a strapless dress
# <startseq> mary đã mặc một chiếc váy không dây <endseq>

# %%
# padding theo độ dài của batch giảm thiểu chi phí
def collate_fcn(batch):
    inputs = [item[0] for item in batch]
    inputs = pad_sequence(inputs, batch_first = True, padding_value = en_vocab.word2index['<pad>'])
    
    targets = [item[1] for item in batch]
    targets = pad_sequence(targets, batch_first=True, padding_value=vi_vocab.word2index['<pad>'])
    return inputs,targets

# %%
# dataloader
train_dataloader = DataLoader(train_dataset, batch_size=32, num_workers=2, collate_fn=collate_fcn)
test_dataloader = DataLoader(test_dataset, batch_size=32, num_workers=2,collate_fn=collate_fcn)

# %%
input = next(iter(test_dataloader))[0][1]
target = next(iter(test_dataloader))[1][1]
print(' '.join([en_vocab.index2word[i.item()] for i in input ]))
print(' '.join([vi_vocab.index2word[i.item()] for i in target ]))
# Out:
# i never realized tom was so stupid <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# <startseq> tôi đã không_thể ngờ được là tom lại ngu_xuẩn đến thế <endseq> <pad> <pad> <pad>

# %%
class Encoder(nn.Module):
    def __init__(self,embedding_size, hidden_size, en_vocab_size,num_layers,bidirectional, p):
        super(Encoder, self).__init__()
        
        self.dropout = nn.Dropout(p)
        self.embedding = nn.Embedding(en_vocab_size, embedding_size)
        self.lstm = nn.LSTM(embedding_size, hidden_size, batch_first= True,
                            num_layers = num_layers ,dropout = p ,bidirectional = bidirectional)
        
    def forward(self,inputs):
        embed = self.embedding(inputs)
        
        outputs, (hidden,cell) = self.lstm(embed)
        return hidden,cell# bidirectional(2)* num_layers, batch_size, hidden_size

# %%
class Decoder(nn.Module):
    def __init__(self,embedidng_size, hidden_size, vi_vocab_size, num_layers,bidirectional, p):
        super(Decoder, self).__init__()
        
        self.embedding = nn.Embedding(vi_vocab_size, embedding_size)
        self.lstm = nn.LSTM(embedding_size, hidden_size, num_layers = num_layers,
                            dropout = p, bidirectional = bidirectional,batch_first = True)
        self.fc = nn.Linear(hidden_size, vi_vocab_size)
    def forward(self, hidden, cell, x):
        x = x.unsqueeze(1)# batch_size,1
        embed = self.embedding(x)
        output, (hidden,cell) = self.lstm(embed,(hidden,cell))
        # output.shape = batch_size,1, hidden_dim
        
        output = self.fc(output)# batch_size,1, vocab_size
        output = output.squeeze(1)# batch_size, vocab_size
        return output, hidden, cell

# %%
class Seq2Seq(nn.Module):
    def __init__(self,embedding_size, hidden_size, en_vocab_size,vi_vocab_size,num_layers,bidirectional , p):
        super(Seq2Seq, self).__init__()
        self.vi_vocab_size = vi_vocab_size
        self.encoder = Encoder(embedding_size, hidden_size, en_vocab_size, num_layers,bidirectional,p)
        self.decoder = Decoder(embedding_size, hidden_size, vi_vocab_size, num_layers,bidirectional,p)
    def forward(self, input, targets, teacher_force_radio = 0.5):
        batch_size = input.size(0)
        targets_len = targets.size(1)
        
        outputs = torch.zeros((batch_size, targets_len, self.vi_vocab_size)).to(device)
        
        
        hidden, cell = self.encoder(input)# bidirectional(2 or 1)* num_layers, batch_size, hidden_size
        
        x = targets[:, 0]# (batch-size,)
        for t in range(1, targets_len):
            output, hidden,cell = self.decoder(hidden,cell,x)
            outputs[:,t-1,:] = output
            
            pred = output.argmax(1) 
            
            x= target[:,t] if teacher_force_radio>0.5 else pred
        return outputs#batch_size, targets_len, vi_vocab_size

# %%
embedding_size = 300
hidden_size = 512
en_vocab_size = en_vocab.n_words
vi_vocab_size = vi_vocab.n_words
num_layers = 2
bidirectional = False
p = 0.3

learning_rate = 0.001

# %%
model = Seq2Seq(embedding_size, hidden_size, en_vocab_size,vi_vocab_size,num_layers,bidirectional , p).to(device)
criterion= nn.CrossEntropyLoss(ignore_index= vi_vocab.word2index['<pad>'])
optimizer = torch.optim.Adam(model.parameters(), lr = learning_rate)

# %%
lst_loss = []
steps_loss = []
epochs = 50
for epoch in range(epochs):
  
  model.train()
  
  for i, (inputs, targets) in enumerate(train_dataloader):
    inputs = inputs.to(device)#batch_size, seq_len
    targets = targets.to(device)

    targets_train  = targets[:,:-1]
    target_criterion = targets[:,1:]

    model.zero_grad()
    outputs = model(inputs, targets_train)
    loss = criterion(outputs.reshape(-1,vi_vocab.n_words), target_criterion.reshape(-1))

    loss.backward()
    optimizer.step()

    steps_loss.append(loss.item())

  print(f'Epoch: {epoch}, Step: {i}, Loss:{np.array(steps_loss).mean():.5f}')
  lst_loss.append(np.array(steps_loss).mean())
  steps_loss =[]
  torch.save(model.state_dict(),'model.pth')
# Out:
# Epoch: 0, Step: 156, Loss:5.70069
# Epoch: 1, Step: 156, Loss:5.26451
# Epoch: 2, Step: 156, Loss:5.01327
# Epoch: 3, Step: 156, Loss:4.78011
# Epoch: 4, Step: 156, Loss:4.55620
# Epoch: 5, Step: 156, Loss:4.31688
# Epoch: 6, Step: 156, Loss:4.08519
# Epoch: 7, Step: 156, Loss:3.84479
# Epoch: 8, Step: 156, Loss:3.60881
# Epoch: 9, Step: 156, Loss:3.35886
# Epoch: 10, Step: 156, Loss:3.09593
# Epoch: 11, Step: 156, Loss:2.84984
# Epoch: 12, Step: 156, Loss:2.61380
# Epoch: 13, Step: 156, Loss:2.38910
# Epoch: 14, Step: 156, Loss:2.18423
# Epoch: 15, Step: 156, Loss:1.97783
# Epoch: 16, Step: 156, Loss:1.77280
# Epoch: 17, Step: 156, Loss:1.61458
# Epoch: 18, Step: 156, Loss:1.47829
# Epoch: 19, Step: 156, Loss:1.34477
# Epoch: 20, Step: 156, Loss:1.21303
# Epoch: 21, Step: 156, Loss:1.08733
# Epoch: 22, Step: 156, Loss:0.97142
# Epoch: 23, Step: 156, Loss:0.88001
# Epoch: 24, Step: 156, Loss:0.79663
# Epoch: 25, Step: 156, Loss:0.72937
# Epoch: 26, Step: 156, Loss:0.67189
# Epoch: 27, Step: 156, Loss:0.62053
# Epoch: 28, Step: 156, Loss:0.58652
# Epoch: 29, Step: 156, Loss:0.54565
# Epoch: 30, Step: 156, Loss:0.51971
# Epoch: 31, Step: 156, Loss:0.48902
# Epoch: 32, Step: 156, Loss:0.47768
# Epoch: 33, Step: 156, Loss:0.46644
# Epoch: 34, Step: 156, Loss:0.44512
# Epoch: 35, Step: 156, Loss:0.42446
# Epoch: 36, Step: 156, Loss:0.40756
# Epoch: 37, Step: 156, Loss:0.39999
# Epoch: 38, Step: 156, Loss:0.38441
# Epoch: 39, Step: 156, Loss:0.38240
# Epoch: 40, Step: 156, Loss:0.36672
# Epoch: 41, Step: 156, Loss:0.34184
# Epoch: 42, Step: 156, Loss:0.32715
# Epoch: 43, Step: 156, Loss:0.30864
# Epoch: 44, Step: 156, Loss:0.29601
# Epoch: 45, Step: 156, Loss:0.28151
# Epoch: 46, Step: 156, Loss:0.26797
# Epoch: 47, Step: 156, Loss:0.26010
# Epoch: 48, Step: 156, Loss:0.24466
# Epoch: 49, Step: 156, Loss:0.23804

# %%
plt.plot(lst_loss)

# %%
def Translation(sentence, max_len = 20):
  
  input= [en_vocab.word2index[word] for word in sentence.split()]
  input = torch.tensor(input, dtype = torch.long).to(device).unsqueeze(0)
  preds = []
  

  model.eval()
  with torch.no_grad():
    hidden, cell = model.encoder(input)
    x = torch.tensor([vi_vocab.word2index['<startseq>']]).to(device)
    for t in range(max_len):
      output, hidden,cell = model.decoder(hidden,cell,x)
      x = output.argmax(1)
      
      if x[0]==vi_vocab.word2index['<endseq>']:
        break
      preds.append(x[0].item())
    return [vi_vocab.index2word[i] for i in preds]

# %%
Translation('he has a foreign car')
# Out:
# ['anh', 'ấy', 'được', 'một', 'cuốn', 'sách']

# %%
 x = targets[:, 0]# (batch-size,)
        for t in range(1, targets_len):
            output, hidden,cell = self.decoder(hidden,cell,x)
            outputs[:,t-1,:] = output
            
            pred = output.argmax(1)
# Out:
# <function ndarray.mean>
